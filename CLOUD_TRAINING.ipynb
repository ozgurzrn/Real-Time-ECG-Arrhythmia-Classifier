# %% [markdown]
# # SOTA ECG Arrhythmia Classifier - Cloud Training
#
# Use this notebook to train the model on Google Colab or Kaggle with GPU acceleration.
#
# ## 1. Upload Data
# Ensure you upload the `src` folder and `data` folder (or at least `mitbih_train.csv` and `mitbih_test.csv`) to the runtime.

# %%
# !pip install torch numpy pandas scipy scikit-learn matplotlib seaborn plotly imbalanced-learn PyWavelets

# %%
import sys
import os

# Ensure src is in path
sys.path.append(os.path.abspath('src'))

# %% [markdown]
# ## 2. Train Model

# %%
# Run the training script directly
# !python train_sota.py

# %% [markdown]
# ## 3. Download Model
# After training, download the `models/sota_ensemble_model.pth` file and place it in your local `models/` directory.
